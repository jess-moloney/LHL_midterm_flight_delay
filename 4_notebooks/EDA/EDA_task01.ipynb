# %% [markdown]
# # EXPLORATORY DATA ANALYSIS QUESTION 1

# %%
import pandas as pd
import math
import requests
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import os

# %%
os.chdir('../..')
df_flights = pd.read_csv('2_data/flights_random_sample.csv')
# Out:
# '/Users/calebward/LHL_midterm_flight_delay'

# %% [markdown]
# # Arrival Delays

# %%
arr_delay_95 = df_flights.arr_delay[
    (df_flights.arr_delay.quantile(0.025)< df_flights.arr_delay) &\
    (df_flights.arr_delay < df_flights.arr_delay.quantile(0.925))]

print(f'mean: {np.mean(arr_delay_95)}')
print(f'median: {np.median(arr_delay_95)}')
print(f'mode: {sci.stats.mode(arr_delay_95, keepdims=False)}')
# Out:
# mean: -3.6727295168420815
# median: -7.0
# mode: ModeResult(mode=-10.0, count=3006)

# %%
ax = sns.distplot(arr_delay_95)
# Out:
# /var/folders/2v/vpx_7m4n5hndgbt2_txpfwxw0000gp/T/ipykernel_41727/2884815316.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(arr_delay_95)

# %%
sm.qqplot(arr_delay_95, line = '45')
plt.show()

# %%
ax = sns.boxplot(x=flight_delay_95)

# %% [markdown]
# # Departure Delays

# %%
dep_delay_95 = df_flights.dep_delay[
    (df_flights.dep_delay.quantile(0.025)< df_flights.dep_delay) &\
    (df_flights.dep_delay < df_flights.dep_delay.quantile(0.925))]

print(f'mean: {np.mean(dep_delay_95)}')
print(f'median: {np.median(dep_delay_95)}')
print(f'mode: {sci.stats.mode(dep_delay_95, keepdims=False)}')
# Out:
# mean: 1.491453999932576
# median: -3.0
# mode: ModeResult(mode=-5.0, count=7879)

# %%
ax = sns.distplot(arr_delay_95)
sm.qqplot(arr_delay_95, line = '45')
plt.show()
ax = sns.boxplot(x=flight_delay_95)
# Out:
# /var/folders/2v/vpx_7m4n5hndgbt2_txpfwxw0000gp/T/ipykernel_41727/2364120095.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(arr_delay_95)
