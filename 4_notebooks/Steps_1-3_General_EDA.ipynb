# %% [markdown]
# # General EDA

# %%
# referenced: https://medium.com/ml-research-lab/chapter-4-knowledge-from-the-data-and-data-exploration-analysis-99a734792733
# https://amueller.github.io/aml/01-ml-workflow/01-data-loading.html

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set() # Setting seaborn as default style even if use only matplotlib
pd.set_option('display.max_rows', None)

# %%
df_flights = pd.read_csv(r'..\2_data\flights_random_sample.csv', sep=',')
df_flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-01-01                 WN                 WN          WN
# 1  2018-01-01                 WN                 WN          WN
# 2  2018-01-01                 WN                 WN          WN
# 3  2018-01-01                 WN                 WN          WN
# 4  2018-01-01                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5431                WN   N291WN               5431
# 1                 989                WN   N287WN                989
# 2                1664                WN   N751SW               1664
# 3                1106                WN   N704SW               1106
# 4                1559                WN   N423WN               1559
#
#    origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0              12889    LAS  ...      986            1.0           0.0
# 1              12889    LAS  ...     1099            0.0           0.0
# 2              12889    LAS  ...     1099            NaN           NaN
# 3              12889    LAS  ...      197            NaN           NaN
# 4              12889    LAS  ...      197           37.0           0.0
#
#   nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0       0.0             0.0                 18.0             NaN
# 1      11.0             0.0                 35.0             NaN
# 2       NaN             NaN                  NaN             NaN
# 3       NaN             NaN                  NaN             NaN
# 4       0.0             0.0                  0.0             NaN
#
#    total_add_gtime  longest_add_gtime  no_name
# 0              NaN                NaN      NaN
# 1              NaN                NaN      NaN
# 2              NaN                NaN      NaN
# 3              NaN                NaN      NaN
# 4              NaN                NaN      NaN
#
# [5 rows x 42 columns]

# %%
df_flights.shape
# Out:
# (100998, 42)

# %% [markdown]
# # Step 1 - Variable Identification

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100998 entries, 0 to 100997
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fl_date              100998 non-null  object
#  1   mkt_unique_carrier   100998 non-null  object
#  2   branded_code_share   100998 non-null  object
#  3   mkt_carrier          100998 non-null  object
#  4   mkt_carrier_fl_num   100998 non-null  int64
#  5   op_unique_carrier    100998 non-null  object
#  6   tail_num             100714 non-null  object
#  7   op_carrier_fl_num    100998 non-null  int64
#  8   origin_airport_id    100998 non-null  int64
#  9   origin               100998 non-null  object
#  10  origin_city_name     100998 non-null  object
#  11  dest_airport_id      100998 non-null  int64
#  12  dest                 100998 non-null  object
#  13  dest_city_name       100998 non-null  object
#  14  crs_dep_time         100998 non-null  int64
#  15  dep_time             99425 non-null   float64
#  16  dep_delay            99380 non-null   float64
#  17  taxi_out             99338 non-null   float64
#  18  wheels_off           99338 non-null   float64
#  19  wheels_on            99303 non-null   float64
#  20  taxi_in              99303 non-null   float64
#  21  crs_arr_time         100998 non-null  int64
#  22  arr_time             99339 non-null   float64
#  23  arr_delay            99110 non-null   float64
#  24  cancelled            100998 non-null  int64
#  25  cancellation_code    1638 non-null    object
#  26  diverted             100998 non-null  int64
#  27  dup                  100998 non-null  object
#  28  crs_elapsed_time     100998 non-null  int64
#  29  actual_elapsed_time  99131 non-null   float64
#  30  air_time             99095 non-null   float64
#  31  flights              100998 non-null  int64
#  32  distance             100998 non-null  int64
#  33  carrier_delay        19146 non-null   float64
#  34  weather_delay        19146 non-null   float64
#  35  nas_delay            19146 non-null   float64
#  36  security_delay       19146 non-null   float64
#  37  late_aircraft_delay  19146 non-null   float64
#  38  first_dep_time       672 non-null     float64
#  39  total_add_gtime      672 non-null     float64
#  40  longest_add_gtime    672 non-null     float64
#  41  no_name              0 non-null       float64
# dtypes: float64(19), int64(11), object(12)
# memory usage: 32.4+ MB

# %%
df_flights.dtypes.value_counts()
# Out:
# float64    19
# object     12
# int64      11
# dtype: int64

# %%
flights_features = df_flights.drop(columns='arr_delay')
flights_features.columns
# Out:
# Index(['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'cancelled', 'cancellation_code',
#        'diverted', 'dup', 'crs_elapsed_time', 'actual_elapsed_time',
#        'air_time', 'flights', 'distance', 'carrier_delay', 'weather_delay',
#        'nas_delay', 'security_delay', 'late_aircraft_delay', 'first_dep_time',
#        'total_add_gtime', 'longest_add_gtime', 'no_name'],
#       dtype='object')

# %%
sns.boxplot(data=flights_features, orient='h')
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >

# %%
# import matplotlib.pyplot as plt
# # create a grid of plots, with 5 rows and 6 columns
# # and place it on a canvas 18 (virtual) inches whide and 6 inches high
# fig, axes = plt.subplots(5, 6, figsize=(18, 6))
# # for each column (and with one axis after another)
# for c, ax in zip(flights_features.columns, axes.ravel()):
#     # create a box-plot grouped by the target variabel
#     df_flights[[c, 'arr_delay']].boxplot(vert=False, by='arr_delay', ax=ax)
#     # remove the x-axis label
#     ax.set_xlabel("")
# # remove the figure title
# plt.suptitle("")
# # fit everything nicely on the plot
# plt.tight_layout()

# %% [markdown]
# Categorical Variables:
# - Nominal data = categorizes and labels variables
# - Ordinal data = categorizes and labels variables + ranks categories in order
#
# Quantitative Variables:
# - Interval data = categorizes and labels variables + ranks categories in order + has known, equal intervals
# - Ratio data = categorizes and labels variables + ranks categories in order + has known, equal intervals + has a true or meaningful zero (can't have less than 0)

# %%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100998 entries, 0 to 100997
# Data columns (total 42 columns):
#   Column               Non-Null Count   Dtype  
# ---  ------               --------------   -----  
#  0   fl_date              100998 non-null  object     quantitative - interval (datetime)
#  1   mkt_unique_carrier   100998 non-null  object     categorical - nominal 
#  2   branded_code_share   100998 non-null  object     categorical - nominal
#  3   mkt_carrier          100998 non-null  object     categorical - nominal
#  4   mkt_carrier_fl_num   100998 non-null  int64      categorical - nominal
#  5   op_unique_carrier    100998 non-null  object     categorical - nominal 
#  6   tail_num             100714 non-null  object     categorical - nominal
#  7   op_carrier_fl_num    100998 non-null  int64      categorical - nominal
#  8   origin_airport_id    100998 non-null  int64      categorical - nominal
#  9   origin               100998 non-null  object     categorical - nominal
#  10  origin_city_name     100998 non-null  object     categorical - nominal
#  11  dest_airport_id      100998 non-null  int64      categorical - nominal
#  12  dest                 100998 non-null  object     categorical - nominal
#  13  dest_city_name       100998 non-null  object     categorical - nominal
#  14  crs_dep_time         100998 non-null  int64      quantitative - interval (datetime)
#  15  dep_time             99425 non-null   float64    quantitative - interval (datetime)
#  16  dep_delay            99380 non-null   float64    quantitative - ratio
#  17  taxi_out             99338 non-null   float64    quantitative - ratio
#  18  wheels_off           99338 non-null   float64    quantitative - interval (datetime)
#  19  wheels_on            99303 non-null   float64    quantitative - interval (datetime)
#  20  taxi_in              99303 non-null   float64    quantitative - ratio
#  21  crs_arr_time         100998 non-null  int64      quantitative - interval (datetime)
#  22  arr_time             99339 non-null   float64    quantitative - interval (datetime)
#  23  arr_delay            99110 non-null   float64    quantitative - ratio
#  24  cancelled            100998 non-null  int64      categorical - nominal (boolean)
#  25  cancellation_code    1638 non-null    object     categorical - nominal
#  26  diverted             100998 non-null  int64      categorical - nominal (boolean)
#  27  dup                  100998 non-null  object     categorical - nominal
#  28  crs_elapsed_time     100998 non-null  int64      quantitative - ratio (scheduled elapsed time of flight, in minutes)
#  29  actual_elapsed_time  99131 non-null   float64    quantitative - ratio (actual elapsed time of flight, in minutes)
#  30  air_time             99095 non-null   float64    quantitative - ratio 
#  31  flights              100998 non-null  int64      quantitative - ratio
#  32  distance             100998 non-null  int64      quantitative - ratio
#  33  carrier_delay        19146 non-null   float64    quantitative - ratio
#  34  weather_delay        19146 non-null   float64    quantitative - ratio
#  35  nas_delay            19146 non-null   float64    quantitative - ratio
#  36  security_delay       19146 non-null   float64    quantitative - ratio
#  37  late_aircraft_delay  19146 non-null   float64    quantitative - ratio
#  38  first_dep_time       672 non-null     float64    quantitative - interval (datetime)
#  39  total_add_gtime      672 non-null     float64    quantitative - ratio
#  40  longest_add_gtime    672 non-null     float64    quantitative - ratio
#  41  no_name              0 non-null       float64    empty

# %%
df_flights.shape
# Out:
# (100998, 42)

# %%
df_flights['mkt_carrier_fl_num'].nunique()
# Out:
# 6771

# %%
df_flights['op_carrier_fl_num'].nunique()
# Out:
# 6773

# %%
# create subset of flights dataframe with quantitative ratio data only

quant_ratio_df = df_flights[[
    'dep_delay',
    'arr_delay',
    'taxi_out',
    'taxi_in',
    'crs_elapsed_time',
    'actual_elapsed_time', 
    'flights',
    'distance',
    'carrier_delay',
    'weather_delay',
    'nas_delay', 
    'security_delay',
    'late_aircraft_delay',
    'total_add_gtime',
    'longest_add_gtime']]

# %%
# create subset of flights dataframe with quantitative interval data only

quant_interval_df = df_flights[[
    'fl_date',
    'crs_dep_time',
    'dep_time',
    'wheels_off',
    'wheels_on',
    'crs_arr_time',
    'arr_time',
    'first_dep_time'
]]

# %%
# create subset of flights dataframe with all quantitative data

numeric_df = pd.concat([quant_ratio_df, quant_interval_df], axis=1)

# %%
# create # create subset of flights dataframe with all categorical data

cat_nom_feats = df_flights.drop(columns=list(numeric_df.columns))
cat_nom_feats.head()
# Out:
#   mkt_unique_carrier branded_code_share mkt_carrier  mkt_carrier_fl_num  \
# 0                 WN                 WN          WN                5431
# 1                 WN                 WN          WN                 989
# 2                 WN                 WN          WN                1664
# 3                 WN                 WN          WN                1106
# 4                 WN                 WN          WN                1559
#
#   op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id origin  \
# 0                WN   N291WN               5431              12889    LAS
# 1                WN   N287WN                989              12889    LAS
# 2                WN   N751SW               1664              12889    LAS
# 3                WN   N704SW               1106              12889    LAS
# 4                WN   N423WN               1559              12889    LAS
#
#   origin_city_name  dest_airport_id dest     dest_city_name  cancelled  \
# 0    Las Vegas, NV            13851  OKC  Oklahoma City, OK          0
# 1    Las Vegas, NV            13871  OMA          Omaha, NE          0
# 2    Las Vegas, NV            13871  OMA          Omaha, NE          0
# 3    Las Vegas, NV            13891  ONT        Ontario, CA          0
# 4    Las Vegas, NV            13891  ONT        Ontario, CA          0
#
#   cancellation_code  diverted dup  air_time  no_name
# 0               NaN         0   N     112.0      NaN
# 1               NaN         0   N     142.0      NaN
# 2               NaN         0   N     132.0      NaN
# 3               NaN         0   N      34.0      NaN
# 4               NaN         0   N      34.0      NaN

# %% [markdown]
# # Step 2 - Univariate Analysis

# %% [markdown]
# ### Quantitative Variables

# %% [markdown]
# For continuous variables: We can build histograms and boxplots for each continuous variable independently. These figures give us an understanding about the variables’ central tendencies and spread.

# %%
df_flights.describe()
# Out:
#        mkt_carrier_fl_num  op_carrier_fl_num  origin_airport_id  \
# count       100998.000000      100998.000000      100998.000000
# mean          2696.313264        2696.343442       12693.375770
# std           1862.177281        1862.418327        1525.958499
# min              1.000000           1.000000       10135.000000
# 25%           1101.000000        1101.000000       11292.000000
# 50%           2272.000000        2272.000000       12889.000000
# 75%           4249.750000        4249.000000       14057.000000
# max           9386.000000        9386.000000       16869.000000
#
#        dest_airport_id   crs_dep_time      dep_time     dep_delay  \
# count    100998.000000  100998.000000  99425.000000  99380.000000
# mean      12662.781501    1329.826620   1334.333437     10.565144
# std        1513.892424     488.757467    502.777726     46.406515
# min       10135.000000       4.000000      1.000000    -35.000000
# 25%       11292.000000     916.000000    919.000000     -6.000000
# 50%       12889.000000    1321.000000   1327.000000     -2.000000
# 75%       14004.000000    1735.000000   1743.000000      6.000000
# max       16869.000000    2359.000000   2400.000000   1503.000000
#
#            taxi_out    wheels_off     wheels_on  ...       distance  \
# count  99338.000000  99338.000000  99303.000000  ...  100998.000000
# mean      17.498168   1358.693431   1460.941784  ...     774.058486
# std       10.066730    504.189165    531.888016  ...     585.277397
# min        0.000000      1.000000      1.000000  ...      31.000000
# 25%       11.000000    934.000000   1046.000000  ...     345.000000
# 50%       15.000000   1341.000000   1500.000000  ...     612.000000
# 75%       20.000000   1758.000000   1911.000000  ...    1012.000000
# max      249.000000   2400.000000   2400.000000  ...    4983.000000
#
#        carrier_delay  weather_delay     nas_delay  security_delay  \
# count   19146.000000   19146.000000  19146.000000    19146.000000
# mean       20.735506       3.208921     16.052491        0.180873
# std        61.536821      25.406923     36.580173        9.093440
# min         0.000000       0.000000      0.000000        0.000000
# 25%         0.000000       0.000000      0.000000        0.000000
# 50%         0.000000       0.000000      3.000000        0.000000
# 75%        18.000000       0.000000     19.000000        0.000000
# max      1503.000000    1000.000000   1283.000000     1078.000000
#
#        late_aircraft_delay  first_dep_time  total_add_gtime  \
# count         19146.000000      672.000000       672.000000
# mean             27.209025     1317.239583        40.453869
# std              51.823107      507.021348        33.922516
# min               0.000000       31.000000         1.000000
# 25%               0.000000      853.000000        17.000000
# 50%               3.000000     1337.000000        30.000000
# 75%              34.000000     1732.250000        52.000000
# max             970.000000     2357.000000       163.000000
#
#        longest_add_gtime  no_name
# count         672.000000      0.0
# mean           39.520833      NaN
# std            32.637231      NaN
# min             1.000000      NaN
# 25%            17.000000      NaN
# 50%            30.000000      NaN
# 75%            50.000000      NaN
# max           163.000000      NaN
#
# [8 rows x 30 columns]

# %%
def uni_analyis_continuous(df, feature, feature_title):
    
    import matplotlib.pyplot as plt
    import matplotlib.transforms as mtrans

    fig, axes = plt.subplots(1,2, sharex=False, figsize=(10,5))
    fig.suptitle(f'Univariate Analysis - {feature_title}')

    sns.boxplot(ax=axes[0], data=df[feature])
    axes[0].set_title(f'{feature_title} Boxplot')
    sns.histplot(ax=axes[1], data=df[feature])
    axes[1].set_title(f'{feature_title} Histogram')

    Minimum = min(df[feature])
    Median = df[feature].median()
    Mean = df[feature].mean()
    Maximum = max(df[feature])
    
    trans = mtrans.blended_transform_factory(fig.transFigure, mtrans.IdentityTransform())

    txt = fig.text(0, 15, f'Minimum : {Minimum}, Median : {Median}, Mean : {Mean}, Maximum : {Maximum}', ha='center', va='center_baseline')
    txt.set_transform(trans)

# %%
for feat in quant_ratio_df:
    uni_analyis_continuous(df_flights, feature=feat, feature_title=feat)

# %% [markdown]
# Much of this data is very skewed - perform transformations / remove outliers before building model?

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# For categorical variables: Create a count plot visualization that shows the frequencies in each category.

# %%
def uni_analyis_categorical(df, feature):
    
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    import matplotlib.transforms as mtrans

    fig, ax = plt.subplots(figsize=(10,5))
    sns.countplot(data = df, y = feature, order = df[feature].value_counts().index, orient='h', palette = 'magma')
    plt.title(f'{feature} frequency')

    cat_count = df[feature].nunique()

    trans = mtrans.blended_transform_factory(fig.transFigure, mtrans.IdentityTransform())

    txt = fig.text(0, 15, f'Number of categories : {cat_count}', ha='center')
    txt.set_transform(trans)

# %%
cat_nom_feats.columns
# Out:
# Index(['mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'cancelled',
#        'cancellation_code', 'diverted', 'dup', 'air_time', 'no_name'],
#       dtype='object')

# %%
for cat in cat_nom_feats.columns:
    print(f'{cat} unique values: {df_flights[cat].nunique()}')
# Out:
# mkt_unique_carrier unique values: 10
# branded_code_share unique values: 15
# mkt_carrier unique values: 10
# mkt_carrier_fl_num unique values: 6771
# op_unique_carrier unique values: 27
# tail_num unique values: 6153
# op_carrier_fl_num unique values: 6773
# origin_airport_id unique values: 369
# origin unique values: 369
# origin_city_name unique values: 362
# dest_airport_id unique values: 370
# dest unique values: 370
# dest_city_name unique values: 363
# cancelled unique values: 2
# cancellation_code unique values: 3
# diverted unique values: 2
# dup unique values: 1
# air_time unique values: 484
# no_name unique values: 0

# %%
df_flights[['origin_airport_id',
'origin',
'origin_city_name',
'dest_airport_id',
'dest',
'dest_city_name']].head()
# Out:
#    origin_airport_id origin origin_city_name  dest_airport_id dest  \
# 0              12889    LAS    Las Vegas, NV            13851  OKC
# 1              12889    LAS    Las Vegas, NV            13871  OMA
# 2              12889    LAS    Las Vegas, NV            13871  OMA
# 3              12889    LAS    Las Vegas, NV            13891  ONT
# 4              12889    LAS    Las Vegas, NV            13891  ONT
#
#       dest_city_name
# 0  Oklahoma City, OK
# 1          Omaha, NE
# 2          Omaha, NE
# 3        Ontario, CA
# 4        Ontario, CA

# %%
df_flights[['mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
       'mkt_carrier_fl_num', 'op_unique_carrier']].head()
# Out:
#   mkt_unique_carrier branded_code_share mkt_carrier  mkt_carrier_fl_num  \
# 0                 WN                 WN          WN                5431
# 1                 WN                 WN          WN                 989
# 2                 WN                 WN          WN                1664
# 3                 WN                 WN          WN                1106
# 4                 WN                 WN          WN                1559
#
#   op_unique_carrier
# 0                WN
# 1                WN
# 2                WN
# 3                WN
# 4                WN

# %%
for feat in ['mkt_unique_carrier', 'branded_code_share', 'mkt_carrier','op_unique_carrier','cancelled','cancellation_code', 'diverted', 'dup']:
    uni_analyis_categorical(df_flights, feature=feat)

# %%
df_flights['origin_city_name'].value_counts()
# Out:
# Chicago, IL                           6383
# Atlanta, GA                           5192
# New York, NY                          4064
# Dallas/Fort Worth, TX                 3752
# Denver, CO                            3288
# Los Angeles, CA                       3235
# Charlotte, NC                         2975
# Houston, TX                           2825
# Washington, DC                        2763
# Las Vegas, NV                         2443
# Phoenix, AZ                           2369
# Seattle, WA                           2310
# San Francisco, CA                     2308
# Detroit, MI                           2261
# Minneapolis, MN                       2072
# Newark, NJ                            1970
# Boston, MA                            1932
# Philadelphia, PA                      1917
# Orlando, FL                           1875
# Salt Lake City, UT                    1651
# Fort Lauderdale, FL                   1313
# Baltimore, MD                         1283
# Miami, FL                             1171
# San Diego, CA                         1130
# Tampa, FL                             1099
# St. Louis, MO                         1067
# Dallas, TX                            1021
# Nashville, TN                         1016
# Portland, OR                           999
# Austin, TX                             939
# San Jose, CA                           917
# Raleigh/Durham, NC                     826
# Sacramento, CA                         824
# New Orleans, LA                        717
# Cincinnati, OH                         687
# Pittsburgh, PA                         655
# Cleveland, OH                          632
# Kansas City, MO                        628
# Honolulu, HI                           625
# Columbus, OH                           561
# Indianapolis, IN                       558
# Oakland, CA                            554
# Milwaukee, WI                          466
# San Antonio, TX                        453
# Fort Myers, FL                         446
# Jacksonville, FL                       429
# Santa Ana, CA                          401
# San Juan, PR                           400
# Hartford, CT                           391
# Louisville, KY                         381
# Albuquerque, NM                        379
# Omaha, NE                              379
# West Palm Beach/Palm Beach, FL         376
# Oklahoma City, OK                      366
# Buffalo, NY                            360
# Norfolk, VA                            359
# Charleston, SC                         348
# Richmond, VA                           340
# Memphis, TN                            312
# Burbank, CA                            293
# Boise, ID                              279
# Kahului, HI                            275
# Knoxville, TN                          263
# Tulsa, OK                              263
# Birmingham, AL                         260
# Ontario, CA                            255
# Grand Rapids, MI                       248
# El Paso, TX                            245
# Spokane, WA                            237
# Savannah, GA                           229
# Providence, RI                         228
# Greer, SC                              224
# Dayton, OH                             217
# Rochester, NY                          215
# Tucson, AZ                             212
# Des Moines, IA                         210
# Albany, NY                             208
# Syracuse, NY                           200
# Anchorage, AK                          199
# Little Rock, AR                        197
# Madison, WI                            192
# Long Beach, CA                         190
# Greensboro/High Point, NC              187
# Fayetteville, AR                       185
# Reno, NV                               183
# Portland, ME                           175
# Kona, HI                               174
# Palm Springs, CA                       174
# Cedar Rapids/Iowa City, IA             169
# White Plains, NY                       167
# Sanford, FL                            161
# Pensacola, FL                          159
# Wichita, KS                            157
# Lexington, KY                          157
# Columbia, SC                           155
# Myrtle Beach, SC                       154
# Burlington, VT                         151
# Fresno, CA                             151
# Lihue, HI                              150
# Manchester, NH                         146
# St. Petersburg, FL                     145
# Colorado Springs, CO                   145
# Harrisburg, PA                         136
# Medford, OR                            133
# Huntsville, AL                         126
# Springfield, MO                        126
# Chattanooga, TN                        122
# Asheville, NC                          120
# Eugene, OR                             119
# Valparaiso, FL                         114
# Bend/Redmond, OR                       114
# Charlottesville, VA                    113
# Bozeman, MT                            113
# Baton Rouge, LA                        106
# Wilmington, NC                         106
# Shreveport, LA                         104
# Jackson/Vicksburg, MS                  103
# Sarasota/Bradenton, FL                 102
# Midland/Odessa, TX                     102
# Santa Barbara, CA                       98
# Fort Wayne, IN                          98
# Fargo, ND                               96
# Sioux Falls, SD                         94
# Green Bay, WI                           92
# Pasco/Kennewick/Richland, WA            92
# Tallahassee, FL                         90
# South Bend, IN                          90
# Akron, OH                               88
# Lubbock, TX                             86
# Punta Gorda, FL                         85
# Aspen, CO                               83
# Appleton, WI                            83
# Panama City, FL                         80
# Moline, IL                              80
# Bismarck/Mandan, ND                     79
# Scranton/Wilkes-Barre, PA               78
# Hilo, HI                                77
# Rapid City, SD                          74
# Missoula, MT                            74
# Roanoke, VA                             73
# Mobile, AL                              73
# Allentown/Bethlehem/Easton, PA          72
# Evansville, IN                          71
# Traverse City, MI                       71
# Peoria, IL                              71
# Billings, MT                            71
# Charleston/Dunbar, WV                   69
# Gainesville, FL                         65
# San Luis Obispo, CA                     64
# Charlotte Amalie, VI                    64
# Mission/McAllen/Edinburg, TX            64
# Corpus Christi, TX                      64
# Flint, MI                               64
# Santa Rosa, CA                          64
# Kalispell, MT                           63
# Rochester, MN                           62
# Amarillo, TX                            62
# Fayetteville, NC                        61
# Bellingham, WA                          60
# Lafayette, LA                           59
# Augusta, GA                             58
# Gulfport/Biloxi, MS                     58
# Kalamazoo, MI                           56
# Jackson, WY                             56
# Bangor, ME                              56
# State College, PA                       56
# Monterey, CA                            55
# Key West, FL                            55
# Grand Junction, CO                      54
# Lansing, MI                             54
# Fairbanks, AK                           54
# Lincoln, NE                             53
# Durango, CO                             51
# Islip, NY                               51
# Montgomery, AL                          50
# Daytona Beach, FL                       50
# Bristol/Johnson City/Kingsport, TN      49
# Newport News/Williamsburg, VA           49
# Harlingen/San Benito, TX                48
# Mosinee, WI                             45
# Elmira/Corning, NY                      45
# Jacksonville/Camp Lejeune, NC           42
# Everett, WA                             41
# Atlantic City, NJ                       41
# Columbia, MO                            40
# St. George, UT                          40
# Idaho Falls, ID                         40
# Helena, MT                              39
# Bloomington/Normal, IL                  39
# Great Falls, MT                         39
# Laredo, TX                              38
# La Crosse, WI                           38
# Newburgh/Poughkeepsie, NY               38
# Alexandria, LA                          38
# Monroe, LA                              37
# Santa Fe, NM                            37
# New Bern/Morehead/Beaufort, NC          37
# Eagle, CO                               37
# Bakersfield, CA                         36
# Killeen, TX                             35
# Minot, ND                               35
# Salisbury, MD                           34
# Ithaca/Cortland, NY                     31
# Casper, WY                              31
# Saginaw/Bay City/Midland, MI            31
# Montrose/Delta, CO                      29
# Champaign/Urbana, IL                    29
# Trenton, NJ                             29
# Brownsville, TX                         28
# Toledo, OH                              28
# Meridian, MS                            28
# Melbourne, FL                           28
# Grand Forks, ND                         27
# Lake Charles, LA                        27
# Concord, NC                             26
# Columbus, GA                            26
# Manhattan/Ft. Riley, KS                 26
# College Station/Bryan, TX               25
# Waco, TX                                24
# Ashland, WV                             24
# Williston, ND                           24
# Lanai, HI                               24
# Hayden, CO                              23
# Guam, TT                                23
# Yuma, AZ                                23
# Plattsburgh, NY                         23
# Abilene, TX                             23
# Sun Valley/Hailey/Ketchum, ID           22
# Duluth, MN                              22
# Erie, PA                                22
# Springfield, IL                         22
# Kapalua, HI                             21
# Lynchburg, VA                           21
# San Angelo, TX                          21
# Aguadilla, PR                           21
# Pullman, WA                             21
# Marquette, MI                           20
# Fort Smith, AR                          20
# Wenatchee, WA                           20
# Grand Island, NE                        19
# Twin Falls, ID                          19
# Hilton Head, SC                         19
# Worcester, MA                           19
# Valdosta, GA                            19
# Brunswick, GA                           19
# Tyler, TX                               19
# Hattiesburg/Laurel, MS                  18
# Redding, CA                             18
# Florence, SC                            18
# Dothan, AL                              17
# Pocatello, ID                           17
# Lawton/Fort Sill, OK                    17
# Stockton, CA                            17
# Joplin, MO                              17
# Pellston, MI                            16
# Roswell, NM                             16
# Flagstaff, AZ                           16
# Walla Walla, WA                         16
# Saipan, TT                              15
# Jamestown, ND                           15
# Latrobe, PA                             15
# Arcata/Eureka, CA                       14
# Pueblo, CO                              14
# Sioux City, IA                          14
# Hoolehua, HI                            14
# Lewiston, ID                            13
# Provo, UT                               13
# Nantucket, MA                           13
# Christiansted, VI                       13
# Binghamton, NY                          13
# Greenville, NC                          13
# Cody, WY                                13
# Longview, TX                            13
# Juneau, AK                              13
# Stillwater, OK                          12
# Niagara Falls, NY                       12
# Rockford, IL                            12
# Hobbs, NM                               12
# Columbus, MS                            12
# New Haven, CT                           11
# Texarkana, AR                           11
# Yakima, WA                              11
# Wichita Falls, TX                       11
# Liberal, KS                             10
# Dubuque, IA                             10
# Lewisburg, WV                           10
# Cape Girardeau, MO                      10
# Devils Lake, ND                         10
# Watertown, NY                           10
# Iron Mountain/Kingsfd, MI               10
# Muskegon, MI                            10
# Rhinelander, WI                          9
# Escanaba, MI                             9
# North Platte, NE                         9
# Sault Ste. Marie, MI                     9
# Vernal, UT                               9
# Scottsbluff, NE                          9
# Williamsport, PA                         9
# Rock Springs, WY                         9
# Alpena, MI                               9
# Hibbing, MN                              8
# Garden City, KS                          8
# Unalaska, AK                             8
# Gunnison, CO                             8
# Waterloo, IA                             8
# Clarksburg/Fairmont, WV                  8
# Albany, GA                               8
# Mammoth Lakes, CA                        8
# Gillette, WY                             8
# Aberdeen, SD                             8
# Hays, KS                                 8
# Belleville, IL                           8
# Kodiak, AK                               7
# Kotzebue, AK                             7
# Nome, AK                                 7
# Bemidji, MN                              7
# Santa Maria, CA                          7
# Paducah, KY                              7
# Moab, UT                                 7
# Brainerd, MN                             7
# Deadhorse, AK                            7
# Portsmouth, NH                           7
# Ogdensburg, NY                           7
# Ketchikan, AK                            7
# Eau Claire, WI                           7
# Salina, KS                               6
# Dickinson, ND                            6
# Staunton, VA                             6
# Quincy, IL                               6
# Ponce, PR                                6
# Bethel, AK                               6
# Martha's Vineyard, MA                    6
# West Yellowstone, MT                     6
# International Falls, MN                  6
# Hancock/Houghton, MI                     6
# North Bend/Coos Bay, OR                  5
# Cheyenne, WY                             5
# Laramie, WY                              5
# Prescott, AZ                             5
# Kearney, NE                              5
# Presque Isle/Houlton, ME                 5
# Elko, NV                                 5
# Cedar City, UT                           5
# Beaumont/Port Arthur, TX                 3
# St. Cloud, MN                            3
# Butte, MT                                3
# Del Rio, TX                              3
# Ogden, UT                                3
# Hagerstown, MD                           2
# Sitka, AK                                2
# Rota, TT                                 2
# Barrow, AK                               2
# Watertown, SD                            2
# Branson, MO                              2
# Owensboro, KY                            1
# Wrangell, AK                             1
# Cordova, AK                              1
# Yakutat, AK                              1
# Pierre, SD                               1
# King Salmon, AK                          1
# Dillingham, AK                           1
# Hyannis, MA                              1
# Name: origin_city_name, dtype: int64

# %% [markdown]
# ### Explore the Target Variable

# %%
# descriptive statistics

df_flights['dep_delay'].describe()
# Out:
# count    99380.000000
# mean        10.565144
# std         46.406515
# min        -35.000000
# 25%         -6.000000
# 50%         -2.000000
# 75%          6.000000
# max       1503.000000
# Name: dep_delay, dtype: float64

# %%
# histogram

sns.histplot(df_flights['dep_delay'])
# Out:
# <AxesSubplot: xlabel='dep_delay', ylabel='Count'>

# %%
filter = df_flights[['month','flights']]
flights_per_month = filter.groupby('month', as_index=False).mean('flights').sort_values(by='month', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 filter = df_flights[['month','flights']]
#       2 flights_per_month = filter.groupby('month', as_index=False).mean('flights').sort_values(by='month', ascending=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['month'] not in index"

# %%
g = sns.lineplot(data=flights_per_month, x='month',y='flights')

# %% [markdown]
# # Step 3 - Bi-Variate Analysis

# %%
quant_ratio_df.columns
# Out:
# Index(['dep_delay', 'arr_delay', 'taxi_out', 'taxi_in', 'crs_elapsed_time',
#        'actual_elapsed_time', 'flights', 'distance', 'carrier_delay',
#        'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
#        'total_add_gtime', 'longest_add_gtime'],
#       dtype='object')

# %%
quant_col_to_drop = ['flights','carrier_delay',
       'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay',
       'total_add_gtime', 'longest_add_gtime']

sns.pairplot(quant_ratio_df.drop(columns=quant_col_to_drop))

# %%
corrmat = quant_ratio_df.drop(columns=quant_col_to_drop).corr()
# top_corr_features = corrmat.index[abs(corrmat["Class"])>0]
plt.figure(figsize=(10,10))
g = sns.heatmap(corrmat,annot=True,cmap="RdYlGn_r")

# %% [markdown]
# Because certain features are highly correlated, we will need to apply dimensionality reduction.

# %% [markdown]
# Do more bivariate analysis here:
# - Categorical & Categorical: A Stacked Column Chart shows how the frequencies are spread between the two categorical variables.
# - Categorical & Continuous: Here, the best visualization in my opinion is building boxplots combined with swarmplots.
