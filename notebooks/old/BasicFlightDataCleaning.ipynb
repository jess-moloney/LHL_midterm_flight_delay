# %%
import pandas as pd
import numpy as np
import os
from modules import connect_lhl
os.chdir('..')
os.getcwd()
# Out:
# '/Users/calebward/LHL_midterm_flight_delay'

# %%
test_conn = connect_lhl.lhl_delay_data('lhl-data-bootcamp.crzjul5qln0e.ca-central-1.rds.amazonaws.com','mid_term_project','lhl_student','lhl_student')
test_conn.connection()
x = test_conn.sample_table('flights','100')
# Out:
# /Users/calebward/LHL_midterm_flight_delay/3_src/modules/connect_lhl.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_return = sqlio.read_sql_query(query, self.connection())

# %%
x
# Out:
#        fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0   2018-02-15                 UA       UA_CODESHARE          UA
# 1   2019-11-20                 UA                 UA          UA
# 2   2018-02-25                 UA                 UA          UA
# 3   2019-07-14                 WN                 WN          WN
# 4   2018-09-30                 UA                 UA          UA
# ..         ...                ...                ...         ...
# 95  2018-02-03                 AA                 AA          AA
# 96  2018-05-31                 DL       DL_CODESHARE          DL
# 97  2019-05-06                 AA       AA_CODESHARE          AA
# 98  2019-08-06                 AA                 AA          AA
# 99  2018-01-28                 AA       AA_CODESHARE          AA
#
#     mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 5411                OO   N168SY               5411
# ...

# %%
df_flight = pd.read_csv('2_data/flights_random_sample.csv')
df_pass = pd.read_csv('2_data/passenger_random_sample.csv')
df_fuel = pd.read_csv('2_data/fuel_consumption.csv')

dfs = [df_flight, df_pass, df_fuel]

# %%
dfs[0].info()

# %%
dfs[1].info()

# %%
dfs[2].info()

# %%
for df in dfs:
    df.dropna(axis = 1, how = 'all', inplace = True)

# %%
df_f = df_flight[['fl_date','mkt_carrier',
'mkt_carrier_fl_num','op_unique_carrier','tail_num','op_carrier_fl_num',
'origin_airport_id','dest_airport_id','crs_dep_time','crs_arr_time',
'crs_elapsed_time','distance','arr_delay']].copy()

# %%
df_f.info()

# %%
df_f[df_f.isnull().any(axis=1)]

# %%
df_f.dropna(axis = 0, how = 'any', inplace=True)
df_f.info()

# %%
df_f

# %%
df_f.T.drop_duplicates().T
df_f.drop('op_unique_carrier', axis = 1, inplace = True)

# %%
df_f = pd.get_dummies(df_f, columns=['tail_num', 'mkt_carrier'])

# %%
df_f[['year', 'month', 'day']] = df_f['fl_date'].str.split('-', expand=True).astype('int')
df_f.drop('fl_date', axis = 1, inplace = True)
df_f.dtypes

# %%
df_f.to_csv('2_data/baseline_data.csv')

# %%
df_f.shape
