# %%
def IFPE_Regression(X_train, y_train, X_test, y_test, regressor, deg=None):
    
    ### INSTANTIATE THE MODEL

    ## LINEAR MODELS

    # ordinary least squares
    if regressor == 'linear':
        from sklearn.linear_model import LinearRegression
        reg = LinearRegression()
    
    # ridge regression
    elif regressor == 'ridge':
        from sklearn.linear_model import Ridge
        reg = Ridge(random_state=0)

    # lasso regression
    elif regressor == 'lasso':
        from sklearn.linear_model import Lasso
        reg = Lasso(random_state=0)

    # polynomial linear regression - need to add polynomial features first
    # https://www.geeksforgeeks.org/python-implementation-of-polynomial-regression/
    # https://scikit-learn.org/stable/modules/linear_model.html#polynomial-regression-extending-linear-models-with-basis-functions
    elif regressor == 'polynomial':
        from sklearn.linear_model import LinearRegression
        from sklearn.preprocessing import PolynomialFeatures
        poly = PolynomialFeatures(degree = deg)
        X_poly_train = poly.fit_transform(X_train)
        X_poly_test = poly.fit_transform(X_test)
        X_train = X_poly_train
        X_test = X_poly_test

        # poly.fit(X_poly, y_train)
        reg = LinearRegression()

    # stochastic gradient descent
    elif regressor == 'sgd':
        from sklearn.linear_model import SGDRegressor
        reg = SGDRegressor(random_state=0)
    
    ## SUPPORT VECTOR MACHINES

    # SVM regression https://scikit-learn.org/stable/modules/svm.html#regression
    elif regressor == 'svm':
        from sklearn import svm
        reg = svm.SVR()

    ## DECISION TREES

    # decision tree
    elif regressor == 'dt':
        from sklearn import tree
        reg = tree.DecisionTreeRegressor(random_state=0)

    ## ENSEMBLE METHODS

    # random forest
    elif regressor =='rf':
        from sklearn.ensemble import RandomForestRegressor
        reg = RandomForestRegressor(max_depth=2, random_state=0)

    # gradient boost
    elif regressor =='gb':
        from sklearn.ensemble import GradientBoostingRegressor
        reg = GradientBoostingRegressor(random_state=0)

    # voting regressor
    elif regressor =='vr':
        from sklearn.ensemble import GradientBoostingRegressor
        from sklearn.ensemble import RandomForestRegressor
        from sklearn.linear_model import LinearRegression
        from sklearn.ensemble import VotingRegressor
        reg1 = GradientBoostingRegressor(random_state=1)
        reg2 = RandomForestRegressor(random_state=1)
        reg3 = LinearRegression()
        reg = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2), ('lr', reg3)])

    # xgboost
    elif regressor == 'xgb':
        import xgboost as xgb
        reg = xgb.XGBRegressor(objective ='reg:squarederror', random_state=0)



    ### FIT THE MODEL

    reg.fit(X_train, y_train)




    ### PREDICT THE RESPONSE FOR THE TEST DATASET

    y_pred = reg.predict(X_test)




    ### EVALUATE THE MODEL

    # Mean Absolute Error
    from sklearn.metrics import mean_absolute_error
    MAE = mean_absolute_error(y_test, y_pred)

    # Root Mean Square Error
    from sklearn.metrics import mean_squared_error
    RMSE = mean_squared_error(y_test, y_pred, squared=False)

    # r2
    from sklearn.metrics import r2_score
    r2 = r2_score(y_test, y_pred)

    # Adjusted r2
    n = len(X_test)
    p = len(X_test[0,:])

    Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)

    ### COMPARE MODELS
    
    import pandas as pd
    model_comparison = pd.DataFrame({
        'Mean Absolute Error': MAE,
        'Root Mean Square Error': RMSE,
        'R Squared': r2,
        'Adjusted R Squared': Adj_r2
    }, index  = [str(regressor)])
    
    return model_comparison

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set() # Setting seaborn as default style even if use only matplotlib
pd.set_option('display.max_rows', None)

# %%
df_flights = pd.read_csv(r'..\flight_data_clean.csv', sep=',')
df_flights = df_flights.drop('Unnamed: 0', axis=1)
df_flights.head()
# Out:
#    mkt_carrier  mkt_carrier_fl_num  tail_num  op_carrier_fl_num  \
# 0            9                5431      1253               5431
# 1            9                 989      1238                989
# 2            9                1664      3796               1664
# 3            9                1106      3562               1106
# 4            9                1559      2065               1559
#
#    origin_airport_id  dest_airport_id  crs_dep_time  crs_arr_time  \
# 0              12889            13851          1930          2350
# 1              12889            13871          2125           155
# 2              12889            13871           650          1120
# 3              12889            13891           735           830
# 4              12889            13891          1740          1835
#
#    crs_elapsed_time  distance  arr_delay  year  month  day
# 0               140       986       19.0  2018      1    1
# 1               150      1099       46.0  2018      1    1
# 2               150      1099       -9.0  2018      1    1
# 3                55       197       -3.0  2018      1    1
# 4                55       197       37.0  2018      1    1

# %%
X = df_flights.drop('arr_delay',axis=1).to_numpy()
y = df_flights['arr_delay'].to_numpy()

# %%
def split_data(data, target=None, percent_test=0.3, dtype='array'):
    # Import train_test_split function
    from sklearn.model_selection import train_test_split

    # Split dataset into training set and test set
    if dtype == 'array':      
        X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=percent_test,random_state=10)
    
        print(f'X_train shape: {X_train.shape}')
        print(f'X_test shape: {X_test.shape}')
        print(f'y_train shape: {y_train.shape}')
        print(f'y_test shape: {y_test.shape}')
    
        return X_train, X_test, y_train, y_test
    
    if dtype == 'df':
        df_train, df_test = train_test_split(data, test_size=percent_test,random_state=10)

        print(f'df_train shape: {df_train.shape}')
        print(f'df_test shape: {df_test.shape}')
    
        return df_train, df_test

# %%
X_train, X_test, y_train, y_test = split_data(data=X, target=y)
# Out:
# X_train shape: (69377, 13)
# X_test shape: (29733, 13)
# y_train shape: (69377,)
# y_test shape: (29733,)

# %%
model_comparison_linear = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='linear', deg=None)
model_comparison_linear
# Out:
#         Mean Absolute Error  Root Mean Square Error  R Squared  \
# linear            24.238396                48.88619   0.008231
#
#         Adjusted R Squared
# linear            0.007797

# %%
model_comparison_ridge = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='ridge', deg=None)
model_comparison_ridge
# Out:
#        Mean Absolute Error  Root Mean Square Error  R Squared  \
# ridge            24.238396                48.88619   0.008231
#
#        Adjusted R Squared
# ridge            0.007797

# %%
model_comparison_lasso = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='lasso', deg=None)
model_comparison_lasso
# Out:
#        Mean Absolute Error  Root Mean Square Error  R Squared  \
# lasso            24.226039               48.883017   0.008359
#
#        Adjusted R Squared
# lasso            0.007926

# %%
model_comparison_poly2 = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='polynomial', deg=2)
model_comparison_poly2
# Out:
#             Mean Absolute Error  Root Mean Square Error  R Squared  \
# polynomial            24.257671               49.305122   -0.00884
#
#             Adjusted R Squared
# polynomial           -0.012416

# %%
model_comparison_poly3 = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='polynomial', deg=3)
model_comparison_poly3
# Out:
#             Mean Absolute Error  Root Mean Square Error     R Squared  \
# polynomial         2.933144e+07            2.862203e+09 -3.399689e+15
#
#             Adjusted R Squared
# polynomial       -3.464951e+15

# %%
model_comparison_sgd = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='sgd', deg=None)
model_comparison_sgd
# Out:
#      Mean Absolute Error  Root Mean Square Error     R Squared  \
# sgd         2.971017e+16            2.996987e+16 -3.727419e+29
#
#      Adjusted R Squared
# sgd       -3.729049e+29

# %%
model_comparison_svm = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='svm', deg=None)
model_comparison_svm
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 model_comparison_svm = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='svm', deg=None)
#       2 model_comparison_svm
#
# Cell In [60], line 88, in IFPE_Regression(X_train, y_train, X_test, y_test, regressor, deg)
#      82     reg = xgb.XGBRegressor(objective ='reg:squarederror', random_state=0)
#      86 ### FIT THE MODEL
# ---> 88 reg.fit(X_train, y_train)
#      93 ### PREDICT THE RESPONSE FOR THE TEST DATASET
#      95 y_pred = reg.predict(X_test)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:251, in BaseLibSVM.fit(self, X, y, sample_weight)
#     248     print("[LibSVM]", end="")
#     250 seed = rnd.randint(np.iinfo("i").max)
# --> 251 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     252 # see comment on the other call to np.iinfo in this file
#     254 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:333, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     319 libsvm.set_verbosity_wrap(self.verbose)
#     321 # we don't pass **self.get_params() to allow subclasses to
#     322 # add other parameters to __init__
#     323 (
#     324     self.support_,
#     325     self.support_vectors_,
#     326     self._n_support,
#     327     self.dual_coef_,
#     328     self.intercept_,
#     329     self._probA,
#     330     self._probB,
#     331     self.fit_status_,
#     332     self._num_iter,
# --> 333 ) = libsvm.fit(
#     334     X,
#     335     y,
#     336     svm_type=solver_type,
#     337     sample_weight=sample_weight,
#     338     class_weight=self.class_weight_,
#     339     kernel=kernel,
#     340     C=self.C,
#     341     nu=self.nu,
#     342     probability=self.probability,
#     343     degree=self.degree,
#     344     shrinking=self.shrinking,
#     345     tol=self.tol,
#     346     cache_size=self.cache_size,
#     347     coef0=self.coef0,
#     348     gamma=self._gamma,
#     349     epsilon=self.epsilon,
#     350     max_iter=self.max_iter,
#     351     random_seed=random_seed,
#     352 )
#     354 self._warn_from_fit_status()
#
# File sklearn\svm\_libsvm.pyx:237, in sklearn.svm._libsvm.fit()
#
# KeyboardInterrupt:

# %%
model_comparison_dt = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='dt', deg=None)
model_comparison_dt
# Out:
#     Mean Absolute Error  Root Mean Square Error  R Squared  Adjusted R Squared
# dt            35.270474               73.538842  -1.244254           -1.245235

# %%
model_comparison_rf = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='rf', deg=None)
model_comparison_rf
# Out:
#     Mean Absolute Error  Root Mean Square Error  R Squared  Adjusted R Squared
# rf            24.201394               48.845569   0.009878            0.009445

# %%
model_comparison_gb = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='gb', deg=None)
model_comparison_gb
# Out:
#     Mean Absolute Error  Root Mean Square Error  R Squared  Adjusted R Squared
# gb            23.995052               48.603529   0.019666            0.019237

# %%
model_comparison_vr = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='vr', deg=None)
model_comparison_vr
# Out:
#     Mean Absolute Error  Root Mean Square Error  R Squared  Adjusted R Squared
# vr            24.308494                48.46062   0.025423            0.024996

# %%
model_comparison_xgb = IFPE_Regression(X_train, y_train, X_test, y_test, regressor='xgb', deg=None)
model_comparison_xgb
# Out:
#      Mean Absolute Error  Root Mean Square Error  R Squared  \
# xgb            24.369545                49.28845  -0.008158
#
#      Adjusted R Squared
# xgb           -0.008599

# %%
model_comparison = pd.concat([model_comparison_linear,model_comparison_ridge,model_comparison_lasso,model_comparison_poly2,model_comparison_poly3,model_comparison_sgd,model_comparison_dt,model_comparison_rf,model_comparison_gb,model_comparison_vr,model_comparison_xgb])

# %%
model_comparison.sort_values('R Squared', ascending=False)
# Out:
#             Mean Absolute Error  Root Mean Square Error     R Squared  \
# vr                 2.430849e+01            4.846062e+01  2.542273e-02
# gb                 2.399505e+01            4.860353e+01  1.966628e-02
# rf                 2.420139e+01            4.884557e+01  9.878050e-03
# lasso              2.422604e+01            4.888302e+01  8.359303e-03
# ridge              2.423840e+01            4.888619e+01  8.230557e-03
# linear             2.423840e+01            4.888619e+01  8.230551e-03
# xgb                2.436955e+01            4.928845e+01 -8.158130e-03
# polynomial         2.425767e+01            4.930512e+01 -8.840289e-03
# dt                 3.527047e+01            7.353884e+01 -1.244254e+00
# polynomial         2.933144e+07            2.862203e+09 -3.399689e+15
# sgd                2.971017e+16            2.996987e+16 -3.727419e+29
#
#             Adjusted R Squared
# vr                2.499642e-02
# gb                1.923745e-02
# rf                9.444940e-03
# lasso             7.925529e-03
# ridge             7.796726e-03
# linear            7.796721e-03
# xgb              -8.599129e-03
# polynomial       -1.241568e-02
# dt               -1.245235e+00
# polynomial       -3.464951e+15
# sgd              -3.729049e+29

# %%
regressor_list = ['linear', 'ridge', 'lasso']

# %%
for regressor in regressor_list:
    df_list = []
    df_list.append(f'model_comparison_{regressor}')
    print(df_list)
# Out:
# ['model_comparison_linear']
# ['model_comparison_ridge']
# ['model_comparison_lasso']

# %%
for regressor in regressor_list:
    df_list = []
    df_list.append(f'model_comparison_{regressor}')
    
for regressor in regressor_list:
    for model in df_list:
        model = IFPE_Regression(X_train, y_train, X_test, y_test, regressor=regressor, deg=None)
        print(model)
# Out:
#        Mean Absolute Error  Root Mean Square Error  R Squared  \
# lasso            24.226039               48.883017   0.008359
#
#        Adjusted R Squared
# lasso            0.007926
