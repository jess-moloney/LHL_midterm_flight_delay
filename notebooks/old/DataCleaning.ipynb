# %%
import pandas as pd
import numpy as np
import os

os.chdir('..')

# %%
df_f_p = pd.read_csv('2_data/Flights_Passenger_Combined_Sample.csv')
df_fuel = pd.read_csv('2_data/fuel_consumption.csv')

# %%
df_f_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 72 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   origin_airport_id      100000 non-null  int64
#  1   origin                 100000 non-null  object
#  2   origin_city_name       100000 non-null  object
#  3   dest_airport_id        100000 non-null  int64
#  4   dest                   100000 non-null  object
#  5   dest_city_name         100000 non-null  object
#  6   air_time               100000 non-null  int64
#  7   distance               100000 non-null  int64
#  8   fl_date                100000 non-null  object
#  9   mkt_unique_carrier     100000 non-null  object
#  10  branded_code_share     100000 non-null  object
#  11  mkt_carrier            100000 non-null  object
#  12  mkt_carrier_fl_num     100000 non-null  int64
#  13  op_unique_carrier      100000 non-null  object
# ...

# %%
df_f_p.dropna(axis = 1, how = 'all', inplace = True)

# %%
df_f_p.drop(['dep_time','taxi_out','wheels_off','wheels_on','taxi_in','arr_time',
'actual_elapsed_time','air_time','carrier_delay','weather_delay','nas_delay',
'security_delay','first_dep_time','total_add_gtime','longest_add_gtime',
'ramp_to_ramp','air_time'], axis = 1, inplace = True)

# %%
df_fuel.drop(['tdomt_gallons','tint_gallons','total_gallons','tdomt_cost','tint_cost','total_cost'], axis = 1, inplace = True)

# %%
df_f_p
# Out:
#        origin_airport_id origin  origin_city_name  dest_airport_id dest  \
# 0                  10821    BWI     Baltimore, MD            12889  LAS
# 1                  14100    PHL  Philadelphia, PA            13487  MSP
# 2                  11292    DEN        Denver, CO            14831  SJC
# 3                  10397    ATL       Atlanta, GA            11298  DFW
# 4                  13487    MSP   Minneapolis, MN            13930  ORD
# ...                  ...    ...               ...              ...  ...
# 99995              12266    IAH       Houston, TX            14193  PNS
# 99996              13930    ORD       Chicago, IL            12339  IND
# 99997              10821    BWI     Baltimore, MD            13303  MIA
# 99998              10397    ATL       Atlanta, GA            13303  MIA
# 99999              12266    IAH       Houston, TX            14747  SEA
#
#               dest_city_name  distance     fl_date mkt_unique_carrier  \
# ...
