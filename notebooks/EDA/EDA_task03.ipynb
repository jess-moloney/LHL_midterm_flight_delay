# %% [markdown]
# #### **Task 3**: Does the weather affect the delay?
# Use the API to pull the weather information for flights. There is no need to get weather for ALL flights. We can choose the right representative sample. Let's focus on four weather types:
# - sunny
# - cloudy
# - rainy
# - snow.
# Test the hypothesis that these 4 delays are from the same distribution. If they are not, which ones are significantly different?

# %%
import pandas as pd
import datetime
import os
os.chdir('../..')

# %%
weather_table = []
with open('data/WeatherStations.txt', 'r') as f:
    for line in f:
        line_lst = []
        line_lst.append(line[0:3])
        line_lst.append(line[3:20])
        line_lst.append(line[20:24])
        line_lst.append(line[26:29])
        line_lst.append(line[30:39])
        line_lst.append(line[39:47])
        line_lst.append(line[47:55])
        weather_table.append(line_lst)

# %%
stations = pd.DataFrame(weather_table[1:-1], columns=weather_table[0])
stations.columns = ['state','station','ICAO','IAT','STN','LAT','LONG']
for col in stations:
    stations[col] = stations[col].str.strip()
stations.drop(['IAT','ICAO','LAT','LONG','station'], inplace = True, axis = 1)
stations = stations.loc[stations.STN != '']

# %% [markdown]
# https://www.cpc.ncep.noaa.gov/products/archives/short_range/2018/03/05/fcst814.20180305.data

# %%
stations.reset_index(inplace=True, drop = True)

# %%
import pandas as pd
import re
import urllib.request
from urllib.error import HTTPError
import time

dates = []
for i in pd.date_range('2017-12-25','2019-12-31').strftime('%Y-%m-%d').tolist():
    dates.append(i.split('-'))

weather = {}
for date in dates:
    year, month, day = date[0], date[1], date[2]
    url = f'https://www.cpc.ncep.noaa.gov/products/archives/short_range/{year}/{month}/{day}/fcst814.{year}{month}{day}.data'
    try:
        data = urllib.request.urlopen(url).read().decode('utf-8')
    except urllib.error.HTTPError as e:
        try:
            if e.code == 404:
                weather[year+month+day] = pd.DataFrame(lst[1:], columns=lst[0]).dropna().drop('YYMMDD/HHMM', axis = 1).copy()
                continue
            else:
                raise
        except:
            raise

    lst = []

    for i in data[47:].split('\n'):
        lst.append(re.split('\s+',i))

    weather[year+month+day] = pd.DataFrame(lst[1:], columns=lst[0]).dropna().drop('YYMMDD/HHMM', axis = 1)

# %%
weather_report = {}
for k in weather.keys():
    df = pd.merge(weather[k], stations, on='STN').drop('STN', axis = 1)
    df.set_index('state',drop=True, inplace = True)

    for col in df:
        df[col] = df[col].astype(float)

    df = df.groupby('state')[['TBLW','TNRM','TABV','PBLW','PNRM','PABV']].sum().div(df.index.value_counts(), axis = 0)

    df['TCAT'] = df[['TBLW','TNRM','TABV']].idxmax(axis=1).astype('category')
    df.TCAT.cat.set_categories(['TBLW','TNRM','TABV'], ordered = True)
    df.TCAT = df.TCAT.cat.codes

    df['PCAT'] = df[['PBLW','PNRM','PABV']].idxmax(axis=1).astype('category')
    df.PCAT.cat.set_categories(['PBLW','PNRM','PABV'],ordered = True)
    df.PCAT = df.PCAT.cat.codes

    df = df[['TCAT','PCAT']]
    weather_report[k] = df

# %% [markdown]
# 0: ABV
# 1: BLW
# 2: NRM

# %%
# make a pickle of the feature engineered data
import pickle
feature_engineered_data6 = weather_report
with open(r'data/feature_engineered_data6.pickle','xb') as weather_data_file:
     pickle.dump(feature_engineered_data6, weather_data_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> # make a pickle of the feature engineered data
#       <a href='vscode-notebook-cell:/Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb#X65sZmlsZQ%3D%3D?line=1'>2</a> import pickle
# ----> <a href='vscode-notebook-cell:/Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb#X65sZmlsZQ%3D%3D?line=2'>3</a> feature_engineered_data6 = weather_report
#       <a href='vscode-notebook-cell:/Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb#X65sZmlsZQ%3D%3D?line=3'>4</a> with open(r'data/feature_engineered_data6.pickle','xb') as weather_data_file:
#       <a href='vscode-notebook-cell:/Users/calebward/LHL_midterm_flight_delay/notebooks/EDA/EDA_task03.ipynb#X65sZmlsZQ%3D%3D?line=4'>5</a>      pickle.dump(feature_engineered_data6, weather_data_file)
#
# NameError: name 'weather_report' is not defined

# %%
with open(r'data/flight_data_500K.pickle','rb') as flight:
     df_flight = pickle.load(flight)
with open(r'data/feature_engineered_data6.pickle','rb') as weather_data_file:
     df_weather = pickle.load(weather_data_file)

# %%
df_flight.columns
# Out:
# Index(['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled', 'diverted', 'dup',
#        'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'flights',
#        'distance'],
#       dtype='object')

# %%
df_flight['origin_state'] = df_flight['origin_city_name'].str[-2:]
df_flight['dest_state'] = df_flight['dest_city_name'].str[-2:]
df_flight.fl_date = pd.to_datetime(df_flight.fl_date)

# %%
df_flight
# Out:
#           fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0      2019-01-05                 AA                 AA          AA
# 1      2019-04-07                 UA       UA_CODESHARE          UA
# 2      2019-10-10                 DL       DL_CODESHARE          DL
# 3      2018-10-11                 DL                 DL          DL
# 4      2018-03-09                 WN                 WN          WN
# ...           ...                ...                ...         ...
# 499995 2018-06-01                 F9                 F9          F9
# 499996 2019-06-27                 WN                 WN          WN
# 499997 2019-12-03                 DL       DL_CODESHARE          DL
# 499998 2018-02-06                 DL       DL_CODESHARE          DL
# 499999 2019-03-30                 WN                 WN          WN
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                      188                AA   N969TW                188
# 1                     4620                AX   N11113               4620
# 2                     3783                OO   N693CA               3783
# 3                     2445                DL   N891AT               2445
# 4                     6144                WN   N792SW               6144
# ...                    ...               ...      ...                ...
# 499995                1639                F9   N706FR               1639
# 499996                 494                WN   N280WN                494
# 499997                5371                9E   N695CA               5371
# 499998                3498                9E   N8908D               3498
# 499999                5339                WN   N8609A               5339
#
#         origin_airport_id origin  ... cancelled  diverted dup  \
# 0                   12339    IND  ...       0.0       0.0   N
# 1                   12896    LBB  ...       0.0       0.0   N
# 2                   13487    MSP  ...       0.0       0.0   N
# 3                   11259    DAL  ...       0.0       0.0   N
# 4                   12953    LGA  ...       0.0       0.0   N
# ...                   ...    ...  ...       ...       ...  ..
# 499995              13204    MCO  ...       0.0       0.0   N
# 499996              14107    PHX  ...       0.0       0.0   N
# 499997              13342    MKE  ...       0.0       0.0   N
# 499998              11193    CVG  ...       0.0       0.0   N
# 499999              11697    FLL  ...       0.0       0.0   N
#
#        crs_elapsed_time  actual_elapsed_time  air_time  flights  distance  \
# 0                 156.0                128.0     107.0      1.0     761.0
# 1                  96.0                 97.0      64.0      1.0     456.0
# 2                 171.0                174.0     129.0      1.0     852.0
# 3                 124.0                109.0      89.0      1.0     721.0
# 4                 180.0                153.0     131.0      1.0     888.0
# ...                 ...                  ...       ...      ...       ...
# 499995            174.0                171.0     153.0      1.0    1066.0
# 499996             80.0                 77.0      65.0      1.0     369.0
# 499997            133.0                123.0     100.0      1.0     738.0
# 499998            104.0                 85.0      68.0      1.0     507.0
# 499999            175.0                162.0     148.0      1.0     957.0
#
#         origin_state  dest_state
# 0                 IN          TX
# 1                 TX          CO
# 2                 MN          TX
# 3                 TX          GA
# 4                 NY          MO
# ...              ...         ...
# 499995            FL          WI
# 499996            AZ          CA
# 499997            WI          NY
# 499998            OH          PA
# 499999            FL          TX
#
# [489978 rows x 34 columns]

# %%
len(df_weather)
# Out:
# 737

# %%
t = pd.json_normalize(df_weather).apply(lambda x : x[0]['TCAT'])
p = pd.json_normalize(df_weather).apply(lambda x : x[0]['PCAT'])

# %%
t = t.T.reset_index().set_axis(['TCAT' for _ in range(t.shape[1])], axis = 0).T
t.columns = [t.columns, t.iloc[0]]
t = t[1:]

# %%
p = p.T.reset_index().set_axis(['PCAT' for _ in range(p.shape[1])], axis = 0).T
p.columns = [p.columns, p.iloc[0]]
p = p[1:]

# %%
t = t.merge(p, left_index=True, right_index=True)

# %%
a = (df_flight.fl_date.apply(lambda x : (x - datetime.timedelta(weeks = 1)).strftime('%Y%m%d')))
# Out:
# 0         20181229
# 1         20190331
# 2         20191003
# 3         20181004
# 4         20180302
#             ...
# 499995    20180525
# 499996    20190620
# 499997    20191126
# 499998    20180130
# 499999    20190323
# Name: fl_date, Length: 489978, dtype: object

# %%
c = a[0:1].apply(lambda x : t.iloc[:, t.columns.get_level_values(1)==x])[0].merge(df_flight, left_index = True, right_on='origin_state')
# Out:
# /var/folders/2v/vpx_7m4n5hndgbt2_txpfwxw0000gp/T/ipykernel_16280/4177437371.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   c = a[0:1].apply(lambda x : t.iloc[:, t.columns.get_level_values(1)==x])[0].merge(df_flight, left_index = True, right_on='origin_state')

# %%
c.columns = ['origin_TCAT', 'origin_PCAT'] + c.columns[2:].to_list()

# %%
c = a[0:1].apply(lambda x : t.iloc[:, t.columns.get_level_values(1)==x])[0].merge(c, right_on='dest_state', left_index=True)
c.columns = ['dest_TCAT', 'dest_PCAT', 'origin_TCAT', 'origin_PCAT'] + c.columns[4:].to_list()
c
# Out:
# /var/folders/2v/vpx_7m4n5hndgbt2_txpfwxw0000gp/T/ipykernel_16280/2419626230.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   c = a[0:1].apply(lambda x : t.iloc[:, t.columns.get_level_values(1)==x])[0].merge(c, right_on='dest_state', left_index=True)
#        dest_TCAT dest_PCAT origin_TCAT origin_PCAT    fl_date  \
# 75             2         0           2           0 2019-01-24
# 494            2         0           2           0 2018-05-22
# 897            2         0           2           0 2018-02-20
# 927            2         0           2           0 2018-05-21
# 1195           2         0           2           0 2019-05-14
# ...          ...       ...         ...         ...        ...
# 476771         0         2           0           0 2018-09-21
# 484712         0         2           0           0 2019-11-09
# 491057         0         2           0           0 2019-04-25
# 497637         0         2           0           0 2018-06-16
# 498692         0         2           0           0 2019-07-14
#
#        mkt_unique_carrier branded_code_share mkt_carrier  mkt_carrier_fl_num  \
# 75                     AS                 AS          AS                  55
# 494                    AS                 AS          AS                  55
# 897                    AS                 AS          AS                  65
# 927                    AS                 AS          AS                 154
# 1195                   AS                 AS          AS                 538
# ...                   ...                ...         ...                 ...
# 476771                 DL                 DL          DL                2942
# 484712                 DL       DL_CODESHARE          DL                4225
# 491057                 DL                 DL          DL                1688
# 497637                 DL       DL_CODESHARE          DL                7381
# 498692                 DL                 DL          DL                 965
#
#        op_unique_carrier  ... diverted  dup  crs_elapsed_time  \
# 75                    AS  ...      0.0    N              85.0
# 494                   AS  ...      0.0    N              56.0
# 897                   AS  ...      0.0    N              42.0
# 927                   AS  ...      0.0    N              84.0
# 1195                  AS  ...      0.0    N              95.0
# ...                  ...  ...      ...  ...               ...
# 476771                DL  ...      0.0    N              57.0
# 484712                OO  ...      0.0    N              86.0
# 491057                DL  ...      0.0    N              57.0
# 497637                OO  ...      0.0    N              80.0
# 498692                DL  ...      0.0    N              62.0
#
#        actual_elapsed_time air_time  flights distance origin_state  \
# 75                    76.0     70.0      1.0    503.0           AK
# 494                   53.0     41.0      1.0    261.0           AK
# 897                   63.0     26.0      1.0     82.0           AK
# 927                   88.0     75.0      1.0    548.0           AK
# 1195                  94.0     86.0      1.0    626.0           AK
# ...                    ...      ...      ...      ...          ...
# 476771                56.0     33.0      1.0    205.0           UT
# 484712                76.0     51.0      1.0    320.0           UT
# 491057                59.0     41.0      1.0    205.0           UT
# 497637                78.0     48.0      1.0    298.0           UT
# 498692                56.0     39.0      1.0    205.0           UT
#
#         dest_state  report_date
# 75              AK   2019-01-17
# 494             AK   2018-05-15
# 897             AK   2018-02-13
# 927             AK   2018-05-14
# 1195            AK   2019-05-07
# ...            ...          ...
# 476771          WY   2018-09-14
# 484712          WY   2019-11-02
# 491057          WY   2019-04-18
# 497637          WY   2018-06-09
# 498692          WY   2019-07-07
#
# [475801 rows x 39 columns]

# %%
import pickle
flight_data_engineered6 = c[['dest_TCAT', 'dest_PCAT', 'origin_TCAT', 'origin_PCAT','arr_delay']]
with open(r'data/flight_data_engineered6.pickle','xb') as weather_data_file:
     pickle.dump(flight_data_engineered6, weather_data_file)
